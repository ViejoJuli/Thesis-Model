# %% [markdown]
# # Langchaing Conversation Model
# The following code allows us to use conversation models with langchain

# %%
import os
import openai
openai.api_type = "azure"
openai.api_base = os.getenv("OPENAI_ENDPOINT") 
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_version = "2023-05-15"

llm = 'gpt-3.5-turbo-rfmanrique'

# %%
# Templates
customer_message = """ Me podrían indicar por favor cual es el horario \
    de atención de la IPS Cuidarte? Necesito sacar una cita \
    con medico general
"""
style = """ Colombian spanish \
    with respectful calm tone
"""
prompt = """ Translate the text \
    into a style that is {style}, \
    text: {text}
"""
prompt1 = """ From the given text, extract the following information: \
    company = The company of the request \
    type = The kind of appoitment \
    
    Format the output as JSON with following the next keys:
    company
    type
    text: {text}
    """

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory

# %%
llm = ChatOpenAI(temperature = 0, engine= llm) # Temperature = 0 means less randomness
memory = ConversationBufferMemory()
conversation = ConversationChain(
    llm = llm,
    memory = memory,
    verbose = False, # !!! With this equls True, shows the prompt followed by chatGPT
)

# prompt_template = ChatPromptTemplate.from_template(prompt)

# # Look for template inputs
# prompt_template.messages[0].prompt.input_variables

# #Assigning input variables
# customer_messages = prompt_template.format_messages(style=style, text=customer_message)

# %%
conversation.predict(input="My name is Julian")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JULINR~1\AppData\Local\Temp/ipykernel_30288/3306366752.py in <module>
# ----> 1 conversation.predict(input="My name is Julian")
#
# C:\Anaconda3\lib\site-packages\langchain\chains\llm.py in predict(self, callbacks, **kwargs)
#     211                 completion = llm.predict(adjective="funny")
#     212         """
# --> 213         return self(kwargs, callbacks=callbacks)[self.output_key]
#     214
#     215     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# C:\Anaconda3\lib\site-packages\langchain\chains\base.py in __call__(self, inputs, return_only_outputs, callbacks)
#     140         except (KeyboardInterrupt, Exception) as e:
#     141             run_manager.on_chain_error(e)
# --> 142             raise e
#     143         run_manager.on_chain_end(outputs)
#     144         return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# C:\Anaconda3\lib\site-packages\langchain\chains\base.py in __call__(self, inputs, return_only_outputs, callbacks)
#     134         try:
#     135             outputs = (
# --> 136                 self._call(inputs, run_manager=run_manager)
#     137                 if new_arg_supported
#     138                 else self._call(inputs)
#
# C:\Anaconda3\lib\site-packages\langchain\chains\llm.py in _call(self, inputs, run_manager)
#      67         run_manager: Optional[CallbackManagerForChainRun] = None,
#      68     ) -> Dict[str, str]:
# ---> 69         response = self.generate([inputs], run_manager=run_manager)
#      70         return self.create_outputs(response)[0]
#      71
#
# C:\Anaconda3\lib\site-packages\langchain\chains\llm.py in generate(self, input_list, run_manager)
#      77         """Generate LLM result from inputs."""
#      78         prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# ---> 79         return self.llm.generate_prompt(
#      80             prompts, stop, callbacks=run_manager.get_child() if run_manager else None
#      81         )
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\base.py in generate_prompt(self, prompts, stop, callbacks)
#     138     ) -> LLMResult:
#     139         prompt_messages = [p.to_messages() for p in prompts]
# --> 140         return self.generate(prompt_messages, stop=stop, callbacks=callbacks)
#     141
#     142     async def agenerate_prompt(
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\base.py in generate(self, messages, stop, callbacks)
#      87         except (KeyboardInterrupt, Exception) as e:
#      88             run_manager.on_llm_error(e)
# ---> 89             raise e
#      90         llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#      91         generations = [res.generations for res in results]
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\base.py in generate(self, messages, stop, callbacks)
#      79         )
#      80         try:
# ---> 81             results = [
#      82                 self._generate(m, stop=stop, run_manager=run_manager)
#      83                 if new_arg_supported
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\base.py in <listcomp>(.0)
#      80         try:
#      81             results = [
# ---> 82                 self._generate(m, stop=stop, run_manager=run_manager)
#      83                 if new_arg_supported
#      84                 else self._generate(m, stop=stop)
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\openai.py in _generate(self, messages, stop, run_manager)
#     269             )
#     270             return ChatResult(generations=[ChatGeneration(message=message)])
# --> 271         response = self.completion_with_retry(messages=message_dicts, **params)
#     272         return self._create_chat_result(response)
#     273
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\openai.py in completion_with_retry(self, **kwargs)
#     230             return self.client.create(**kwargs)
#     231
# --> 232         return _completion_with_retry(**kwargs)
#     233
#     234     def _combine_llm_outputs(self, llm_outputs: List[Optional[dict]]) -> dict:
#
# C:\Anaconda3\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     287         @functools.wraps(f)
#     288         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289             return self(f, *args, **kw)
#     290
#     291         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# C:\Anaconda3\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     377         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378         while True:
# --> 379             do = self.iter(retry_state=retry_state)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
#
# C:\Anaconda3\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     312         is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313         if not (is_explicit_retry or self.retry(retry_state)):
# --> 314             return fut.result()
#     315
#     316         if self.after is not None:
#
# C:\Anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     436                     raise CancelledError()
#     437                 elif self._state == FINISHED:
# --> 438                     return self.__get_result()
#     439
#     440                 self._condition.wait(timeout)
#
# C:\Anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     388         if self._exception:
#     389             try:
# --> 390                 raise self._exception
#     391             finally:
#     392                 # Break a reference cycle with the exception in self._exception
#
# C:\Anaconda3\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
# --> 382                     result = fn(*args, **kwargs)
#     383                 except BaseException:  # noqa: B902
#     384                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\openai.py in _completion_with_retry(**kwargs)
#     228         @retry_decorator
#     229         def _completion_with_retry(**kwargs: Any) -> Any:
# --> 230             return self.client.create(**kwargs)
#     231
#     232         return _completion_with_retry(**kwargs)
#
# C:\Anaconda3\lib\site-packages\openai\api_resources\chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# C:\Anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     147             url,
#     148             params,
# --> 149         ) = cls.__prepare_create_request(
#     150             api_key, api_base, api_type, api_version, organization, **params
#     151         )
#
# C:\Anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in __prepare_create_request(cls, api_key, api_base, api_type, api_version, organization, **params)
#     111             organization=organization,
#     112         )
# --> 113         url = cls.class_url(engine, api_type, api_version)
#     114         return (
#     115             deployment_id,
#
# C:\Anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in class_url(cls, engine, api_type, api_version)
#      42                     "You must provide the deployment name in the 'engine' parameter to access the Azure OpenAI service"
#      43                 )
# ---> 44             extn = quote_plus(engine)
#      45             return "/%s/%s/%s/%s?api-version=%s" % (
#      46                 cls.azure_api_prefix,
#
# C:\Anaconda3\lib\urllib\parse.py in quote_plus(string, safe, encoding, errors)
#     885     else:
#     886         space = b' '
# --> 887     string = quote(string, safe + space, encoding, errors)
#     888     return string.replace(' ', '+')
#     889
#
# C:\Anaconda3\lib\urllib\parse.py in quote(string, safe, encoding, errors)
#     869         if errors is not None:
#     870             raise TypeError("quote() doesn't support 'errors' for bytes")
# --> 871     return quote_from_bytes(string, safe)
#     872
#     873 def quote_plus(string, safe='', encoding=None, errors=None):
#
# C:\Anaconda3\lib\urllib\parse.py in quote_from_bytes(bs, safe)
#     894     """
#     895     if not isinstance(bs, (bytes, bytearray)):
# --> 896         raise TypeError("quote_from_bytes() expected bytes")
#     897     if not bs:
#     898         return ''
#
# TypeError: quote_from_bytes() expected bytes

# %%
conversation.predict(input="Whats my name")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\JULINR~1\AppData\Local\Temp/ipykernel_30288/3245999042.py in <module>
# ----> 1 conversation.predict(input="Whats my name")
#
# C:\Anaconda3\lib\site-packages\langchain\chains\llm.py in predict(self, callbacks, **kwargs)
#     211                 completion = llm.predict(adjective="funny")
#     212         """
# --> 213         return self(kwargs, callbacks=callbacks)[self.output_key]
#     214
#     215     async def apredict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#
# C:\Anaconda3\lib\site-packages\langchain\chains\base.py in __call__(self, inputs, return_only_outputs, callbacks)
#     140         except (KeyboardInterrupt, Exception) as e:
#     141             run_manager.on_chain_error(e)
# --> 142             raise e
#     143         run_manager.on_chain_end(outputs)
#     144         return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# C:\Anaconda3\lib\site-packages\langchain\chains\base.py in __call__(self, inputs, return_only_outputs, callbacks)
#     134         try:
#     135             outputs = (
# --> 136                 self._call(inputs, run_manager=run_manager)
#     137                 if new_arg_supported
#     138                 else self._call(inputs)
#
# C:\Anaconda3\lib\site-packages\langchain\chains\llm.py in _call(self, inputs, run_manager)
#      67         run_manager: Optional[CallbackManagerForChainRun] = None,
#      68     ) -> Dict[str, str]:
# ---> 69         response = self.generate([inputs], run_manager=run_manager)
#      70         return self.create_outputs(response)[0]
#      71
#
# C:\Anaconda3\lib\site-packages\langchain\chains\llm.py in generate(self, input_list, run_manager)
#      77         """Generate LLM result from inputs."""
#      78         prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# ---> 79         return self.llm.generate_prompt(
#      80             prompts, stop, callbacks=run_manager.get_child() if run_manager else None
#      81         )
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\base.py in generate_prompt(self, prompts, stop, callbacks)
#     138     ) -> LLMResult:
#     139         prompt_messages = [p.to_messages() for p in prompts]
# --> 140         return self.generate(prompt_messages, stop=stop, callbacks=callbacks)
#     141
#     142     async def agenerate_prompt(
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\base.py in generate(self, messages, stop, callbacks)
#      87         except (KeyboardInterrupt, Exception) as e:
#      88             run_manager.on_llm_error(e)
# ---> 89             raise e
#      90         llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#      91         generations = [res.generations for res in results]
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\base.py in generate(self, messages, stop, callbacks)
#      79         )
#      80         try:
# ---> 81             results = [
#      82                 self._generate(m, stop=stop, run_manager=run_manager)
#      83                 if new_arg_supported
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\base.py in <listcomp>(.0)
#      80         try:
#      81             results = [
# ---> 82                 self._generate(m, stop=stop, run_manager=run_manager)
#      83                 if new_arg_supported
#      84                 else self._generate(m, stop=stop)
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\openai.py in _generate(self, messages, stop, run_manager)
#     269             )
#     270             return ChatResult(generations=[ChatGeneration(message=message)])
# --> 271         response = self.completion_with_retry(messages=message_dicts, **params)
#     272         return self._create_chat_result(response)
#     273
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\openai.py in completion_with_retry(self, **kwargs)
#     230             return self.client.create(**kwargs)
#     231
# --> 232         return _completion_with_retry(**kwargs)
#     233
#     234     def _combine_llm_outputs(self, llm_outputs: List[Optional[dict]]) -> dict:
#
# C:\Anaconda3\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     287         @functools.wraps(f)
#     288         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289             return self(f, *args, **kw)
#     290
#     291         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# C:\Anaconda3\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     377         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378         while True:
# --> 379             do = self.iter(retry_state=retry_state)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
#
# C:\Anaconda3\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     312         is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313         if not (is_explicit_retry or self.retry(retry_state)):
# --> 314             return fut.result()
#     315
#     316         if self.after is not None:
#
# C:\Anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     436                     raise CancelledError()
#     437                 elif self._state == FINISHED:
# --> 438                     return self.__get_result()
#     439
#     440                 self._condition.wait(timeout)
#
# C:\Anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     388         if self._exception:
#     389             try:
# --> 390                 raise self._exception
#     391             finally:
#     392                 # Break a reference cycle with the exception in self._exception
#
# C:\Anaconda3\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
# --> 382                     result = fn(*args, **kwargs)
#     383                 except BaseException:  # noqa: B902
#     384                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# C:\Anaconda3\lib\site-packages\langchain\chat_models\openai.py in _completion_with_retry(**kwargs)
#     228         @retry_decorator
#     229         def _completion_with_retry(**kwargs: Any) -> Any:
# --> 230             return self.client.create(**kwargs)
#     231
#     232         return _completion_with_retry(**kwargs)
#
# C:\Anaconda3\lib\site-packages\openai\api_resources\chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# C:\Anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     147             url,
#     148             params,
# --> 149         ) = cls.__prepare_create_request(
#     150             api_key, api_base, api_type, api_version, organization, **params
#     151         )
#
# C:\Anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in __prepare_create_request(cls, api_key, api_base, api_type, api_version, organization, **params)
#     111             organization=organization,
#     112         )
# --> 113         url = cls.class_url(engine, api_type, api_version)
#     114         return (
#     115             deployment_id,
#
# C:\Anaconda3\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py in class_url(cls, engine, api_type, api_version)
#      42                     "You must provide the deployment name in the 'engine' parameter to access the Azure OpenAI service"
#      43                 )
# ---> 44             extn = quote_plus(engine)
#      45             return "/%s/%s/%s/%s?api-version=%s" % (
#      46                 cls.azure_api_prefix,
#
# C:\Anaconda3\lib\urllib\parse.py in quote_plus(string, safe, encoding, errors)
#     885     else:
#     886         space = b' '
# --> 887     string = quote(string, safe + space, encoding, errors)
#     888     return string.replace(' ', '+')
#     889
#
# C:\Anaconda3\lib\urllib\parse.py in quote(string, safe, encoding, errors)
#     869         if errors is not None:
#     870             raise TypeError("quote() doesn't support 'errors' for bytes")
# --> 871     return quote_from_bytes(string, safe)
#     872
#     873 def quote_plus(string, safe='', encoding=None, errors=None):
#
# C:\Anaconda3\lib\urllib\parse.py in quote_from_bytes(bs, safe)
#     894     """
#     895     if not isinstance(bs, (bytes, bytearray)):
# --> 896         raise TypeError("quote_from_bytes() expected bytes")
#     897     if not bs:
#     898         return ''
#
# TypeError: quote_from_bytes() expected bytes

# %%
# This allows to see the memory of the chat
print(memory.buffer)
#memory.load_memory_variables({})
#memory.savecontext({input:"Hi", output:"What's up?"}) # To manipulate the memory
# Out:
# Human: My name is Julian
# AI: Hello Julian! It's nice to meet you. How can I assist you today?
# Human: Whats my name
# AI: Your name is Julian.

# %%
# !!!There is also another kind of memory
from langchain.memory import ConversationBufferWindowMemory

memory = ConversationBufferWindowMemory(k=1) # k = 1 means the lag of the conversation

#from langchain.memory import ConversationTokenBufferMemory # with tokens
#memory = ConversationTokenBufferMemory(llm=llm, max_token_limit=50)

#from langchain.memory import ConversationSummaryBufferMemory # !!!with summary
#memory = ConversationSummaryBufferMemory(llm=llm, max_token_limit=50)
# Out:
# ¿Podrían por favor informarme cuál es el horario de atención de la IPS Cuidarte? Necesito agendar una cita con el médico general.
